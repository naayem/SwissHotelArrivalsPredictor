# %%
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the data (from Jan 2009 to December 2020)
data = pd.read_csv('Tourism.csv', delimiter=';', header=1)

# %%
data.head(12)
# Out:
#     Year      Month       Canton  \
# 0   2009    January  Switzerland
# 1   2009   February  Switzerland
# 2   2009      March  Switzerland
# 3   2009      April  Switzerland
# 4   2009        May  Switzerland
# 5   2009       June  Switzerland
# 6   2009       July  Switzerland
# 7   2009     August  Switzerland
# 8   2009  September  Switzerland
# 9   2009    October  Switzerland
# 10  2009   November  Switzerland
# 11  2009   December  Switzerland
#
#    Visitors' country of residence - total Arrivals Switzerland Arrivals  \
# 0                                          1064111               528523
# 1                                          1089483               521069
# 2                                          1196859               567431
# 3                                          1045137               468308
# 4                                          1214666               548389
# 5                                          1446249               638139
# ...

# %%
#Reindexing
data.index = pd.date_range('2009-01-01', '2020-12-01', freq= 'MS')

# %%
#Drop useless columns
data = data.drop(['Year', 'Month', 'Canton'], axis = 1)

# %%
data
# Out:
#            Visitors' country of residence - total Arrivals  \
# 2009-01-01                                         1064111
# 2009-02-01                                         1089483
# 2009-03-01                                         1196859
# 2009-04-01                                         1045137
# 2009-05-01                                         1214666
# ...                                                    ...
# 2020-08-01                                         1525425
# 2020-09-01                                         1291992
# 2020-10-01                                          949466
# 2020-11-01                                             ...
# 2020-12-01                                             ...
#
#            Switzerland Arrivals Baltic States Arrivals Germany Arrivals  \
# 2009-01-01               528523                   1250           154530
# 2009-02-01               521069                    864           160914
# ...

# %%
#Replacing '...' values by 0 and Converting arrival string values into integer values
for column in data.columns:
    data[column] = data[column].apply(lambda x : 0 if x == '...' else int(x))

# %%
data
# Out:
#             Visitors' country of residence - total Arrivals  \
# 2009-01-01                                          1064111
# 2009-02-01                                          1089483
# 2009-03-01                                          1196859
# 2009-04-01                                          1045137
# 2009-05-01                                          1214666
# ...                                                     ...
# 2020-08-01                                          1525425
# 2020-09-01                                          1291992
# 2020-10-01                                           949466
# 2020-11-01                                                0
# 2020-12-01                                                0
#
#             Switzerland Arrivals  Baltic States Arrivals  Germany Arrivals  \
# 2009-01-01                528523                    1250            154530
# 2009-02-01                521069                     864            160914
# ...

# %%
#Plot total number of Arrivals from Jan 2009 to March 2020 (Lockdown in Switzerland)
plt.figure(figsize= (19,6 ))
plt.plot(data[:datetime(2020,3,1)].index, data["Visitors' country of residence - total Arrivals"][:datetime(2020,3,1)], color = 'orange')
plt.plot(data[datetime(2020,2,1):datetime(2020,3,1)].index, data["Visitors' country of residence - total Arrivals"][datetime(2020,2,1):datetime(2020,3,1)], color = 'r')
plt.title('Total Arrivals in Switzerland from 2009 to 2020')
plt.xlabel('Time')
plt.ylabel('Arrivals')
plt.grid(color='k', linestyle='-', linewidth=0.1)
plt.show()

# %%
Arrivals = data["Visitors' country of residence - total Arrivals"]

# %% [markdown]
# ## AR Base Modelisation

# %%
def Linear_Regressions_for_all_Turning_Points(claims, start_dates, end_dates, Trends = False):
    MAE = np.zeros(4)
    for i in range(4):
        train_end = start_dates[i]
        test_end = end_dates[i]
        
        True_Claims_Values = claims[train_end+relativedelta(day=+1) : test_end].drop(['t-1', 'Jobs', 'Welfare...Unemployment'], axis = 1)
        Baseline_Predictions = True_Claims_Values.Claims.copy()
    
        for train_last in True_Claims_Values.index: 
        
            train_set = claims[ :train_last -timedelta(days=1)]
            test_set = claims[train_last :]
        
            if (Trends):
                X_train = train_set.drop(['Claims'], axis = 1).values
                X_test = test_set.drop(['Claims'], axis = 1).values
            else:
                X_train = train_set.drop(['Claims','Jobs', 'Welfare...Unemployment'], axis = 1).values
                X_test = test_set.drop(['Claims','Jobs', 'Welfare...Unemployment'], axis = 1).values
            
            y_train = train_set.Claims.values
            y_test = test_set.Claims.values
        
            lr = LinearRegression()
            lr.fit(X_train, y_train)
           
            if(train_last == True_Claims_Values.index[-1]):
                if Trends:
                    print('For the turning point number {}, we have : '.format(i+1))
                    print('The intercept value is:', lr.intercept_ )
                    print('The final estimation of lag(y,-1) is: {}'.format(lr.coef_[2]))
                    print('The final estimation of the Jobs trend is: {}'.format(lr.coef_[0]))
                    print('The final estimation of the Welfare Unemployment trend is: {}'.format(lr.coef_[1]))
                else:
                    print('For the turning point number {}, we have : '.format(i+1))
                    print('The intercept value is:', lr.intercept_ )
                    print('The final estimation of lag(y,-1) is: {}'.format(lr.coef_[0]))

            pred = lr.predict(X_test)
            
            Baseline_Predictions[train_last] = pred[0]
           
        MAE[i] = mean_absolute_error(True_Claims_Values.Claims, Baseline_Predictions)
        print('MAE : {}\n'.format(MAE[i]))
       
    return MAE
